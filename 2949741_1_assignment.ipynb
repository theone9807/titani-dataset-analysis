# %% [markdown]
# # Instructions:

# %% [markdown]
# Please answer the following questions as thoroughly as possible to produce correct output and to clearly interpret the results if the question asks for it.

# %% [markdown]
# ## Question 1 (50 points)

# %% [markdown]
# ### Import neccessary libraries:

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ### Load the dataset as excel 'titanic.xls'

# %%
data_filename = '2949741_2_titanic.csv'
data = pd.read_csv(data_filename)

# %% [markdown]
# ### Show the head of the dataframe and briefly explain the data

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# #### This dataset contains 14 columns.

# %% [markdown]
# ### Return some info on the data and briefly explain what the categories mean

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 14 columns):
# pclass       1301 non-null float64
# survived     1301 non-null float64
# name         1301 non-null object
# sex          1301 non-null object
# age          1040 non-null float64
# sibsp        1301 non-null float64
# parch        1301 non-null float64
# ticket       1300 non-null object
# fare         1300 non-null float64
# cabin        295 non-null object
# embarked     1299 non-null object
# boat         486 non-null object
# body         118 non-null float64
# home.dest    745 non-null object
# dtypes: float64(7), object(7)
# memory usage: 143.5+ KB

# %% [markdown]
# #### The float caterfory means this column consists of decimal. The object means this column consists of text information.

# %% [markdown]
# ### 'Describe' the main statistical features of the data

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1301.000000  1301.000000  1040.000000  1301.000000  1301.000000
# mean      2.290546     0.384320    29.902083     0.499616     0.387394
# std       0.838577     0.486621    14.430969     1.044123     0.867691
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1300.000000  118.000000
# mean     33.427608  156.898305
# std      51.890374   95.731229
# min       0.000000    1.000000
# 25%       7.895800   70.500000
# 50%      14.456250  151.000000
# 75%      31.275000  248.000000
# max     512.329200  327.000000

# %% [markdown]
# ### Include 50% to 100% percentile with 5% increments for the 'age' column in the describe method output

# %%
age = data['age']

#percentile
per = [0.50, 0.55, .60, .65, .70, .75, .80, .85, .90, .95, 1.00]
age.describe(percentiles= per)
# Out:
# count    1040.000000
# mean       29.902083
# std        14.430969
# min         0.166700
# 50%        28.000000
# 55.0%      30.000000
# 60%        31.000000
# 65%        33.000000
# 70%        36.000000
# 75%        39.000000
# 80%        42.000000
# 85%        45.000000
# 90%        50.000000
# 95%        57.000000
# 100%       80.000000
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# ### What is the 80% percentile of the 'age' column?

# %%
age = data['age']

#percentile
per = [0.80]
age.describe(percentiles= per)
# Out:
# count    1040.000000
# mean       29.902083
# std        14.430969
# min         0.166700
# 50%        28.000000
# 80%        42.000000
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Create a sub dataframe where the age of passengers is above the 80% percentile calculated above

# %%
age80 = pd.DataFrame(age[age> 42.000000])
age80.head()
# Out:
#      age
# 5   48.0
# 6   63.0
# 8   53.0
# 9   71.0
# 10  47.0

# %% [markdown]
# ### Count the number of passengers in first class

# %%
len(data['pclass'][data['pclass'] == 1.0])
# Out:
# 323

# %% [markdown]
# ### Create a new column called 'older than 90% percentile' where it's true/false if the passenger is older/younger than the 90% percentile

# %%
def check_older(a):
    
    if a > 50.000000:
        return True
    return False
    
data['Older Than 90%'] = data['age'].apply(check_older)
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  Older Than 90%
# 0                     St Louis, MO           False
# 1  Montreal, PQ / Chesterville, ON           False
# 2  Montreal, PQ / Chesterville, ON           False
# 3  Montreal, PQ / Chesterville, ON           False
# 4  Montreal, PQ / Chesterville, ON           False

# %% [markdown]
# ### Group the 'fare' column by the class of passenger and get the mean fare price for each class

# %%
class1 = data[['pclass', 'fare']][data['pclass'] == 1.0]
class2 = data[['pclass', 'fare']][data['pclass'] == 2.0]
class3 = data[['pclass', 'fare']][data['pclass'] == 3.0]
print('Mean Fare Class1: ',class1['fare'].mean())
print('Mean Fare Class2: ',class2['fare'].mean())
print('Mean Fare Class3: ',class3['fare'].mean())
f1 = class1['fare'].mean()
f2 = class2['fare'].mean()
f3 = class3['fare'].mean()
# sns.catplot('fare', data= data, hue= 'pclass', kind='count')
# Out:
# Mean Fare Class1:  87.50899164086688
# Mean Fare Class2:  21.179196389891697
# Mean Fare Class3:  13.319784714285714

# %% [markdown]
# ### Plot the bar chart for the avg fare grouped by class

# %%
barplot = pd.DataFrame([f1, f2,f3], index= ['class1', 'class2', 'class3'])
barplot.plot.bar()
plt.ylabel('Avg fare')
# Out:
# Text(0, 0.5, 'Avg fare')

# %% [markdown]
# ### Getting the number of outliers: define the upper bound and lower bound for the 'fare' column at 95% or 5% and count how many passengers are considered outliers

# %%
#Answer here
data['fare'].describe(percentiles= [.05, .95])
# Out:
# count    1300.000000
# mean       33.427608
# std        51.890374
# min         0.000000
# 5%          7.225000
# 50%        14.456250
# 95%       133.692500
# max       512.329200
# Name: fare, dtype: float64

# %%
#number of outliners
len(data[data['fare']> 133.6925]) + len(data[data['fare'] < 7.2250])
# Out:
# 120

# %% [markdown]
# ### Replace outliers in the dataframe by the mean of the 'fare' column

# %%
def replace(f):
    
    if (f > 133.6925 or f < 7.2250):
        return 33.4276
    return f
    
data['fare'] = data['fare'].apply(replace)
data
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1.0       1.0                      Aubart, Mme. Leontine Pauline
# 13       1.0       1.0                       Barber, Miss. Ellen "Nellie"
# 14       1.0       1.0               Barkworth, Mr. Algernon Henry Wilson
# 15       1.0       0.0                                Baumann, Mr. John D
# 16       1.0       0.0                           Baxter, Mr. Quigg Edmond
# 17       1.0       1.0    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1.0       1.0                              Bazzani, Miss. Albina
# 19       1.0       0.0                               Beattie, Mr. Thomson
# 20       1.0       1.0                      Beckwith, Mr. Richard Leonard
# 21       1.0       1.0   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1.0       1.0                              Behr, Mr. Karl Howell
# 23       1.0       1.0                              Bidois, Miss. Rosalie
# 24       1.0       1.0                                  Bird, Miss. Ellen
# 25       1.0       0.0                                Birnbaum, Mr. Jakob
# 26       1.0       1.0                            Bishop, Mr. Dickinson H
# 27       1.0       1.0            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1.0       1.0                             Bissette, Miss. Amelia
# 29       1.0       1.0          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ...      ...       ...                                                ...
# 1281     3.0       0.0                                    Vovk, Mr. Janko
# 1282     3.0       0.0                               Waelens, Mr. Achille
# 1283     3.0       0.0                                Ware, Mr. Frederick
# 1284     3.0       0.0                        Warren, Mr. Charles William
# 1285     3.0       0.0                                  Webber, Mr. James
# 1286     3.0       0.0                                Wenzel, Mr. Linhart
# 1287     3.0       1.0    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1288     3.0       0.0                   Widegren, Mr. Carl/Charles Peter
# 1289     3.0       0.0                          Wiklund, Mr. Jakob Alfred
# 1290     3.0       0.0                            Wiklund, Mr. Karl Johan
# 1291     3.0       1.0                   Wilkes, Mrs. James (Ellen Needs)
# 1292     3.0       0.0                   Willer, Mr. Aaron ("Abi Weller")
# 1293     3.0       0.0                                 Willey, Mr. Edward
# 1294     3.0       0.0                  Williams, Mr. Howard Hugh "Harry"
# 1295     3.0       0.0                               Williams, Mr. Leslie
# 1296     3.0       0.0                                Windelov, Mr. Einar
# 1297     3.0       0.0                                   Wirz, Mr. Albert
# 1298     3.0       0.0                             Wiseman, Mr. Phillippe
# 1299     3.0       0.0                          Wittevrongel, Mr. Camille
# 1300     3.0       0.0                                Yasbeck, Mr. Antoni
# 1301     NaN       NaN                                                NaN
# 1302     NaN       NaN                                                NaN
# 1303     NaN       NaN                                                NaN
# 1304     NaN       NaN                                                NaN
# 1305     NaN       NaN                                                NaN
# 1306     NaN       NaN                                                NaN
# 1307     NaN       NaN                                                NaN
# 1308     NaN       NaN                                                NaN
# 1309     NaN       NaN                                                NaN
# 1310     NaN       NaN                                                NaN
#
#          sex      age  sibsp  parch            ticket     fare    cabin  \
# 0     female  29.0000    0.0    0.0             24160  33.4276       B5
# 1       male   0.9167    1.0    2.0            113781  33.4276  C22 C26
# 2     female   2.0000    1.0    2.0            113781  33.4276  C22 C26
# 3       male  30.0000    1.0    2.0            113781  33.4276  C22 C26
# 4     female  25.0000    1.0    2.0            113781  33.4276  C22 C26
# 5       male  48.0000    0.0    0.0             19952  26.5500      E12
# 6     female  63.0000    1.0    0.0             13502  77.9583       D7
# 7       male  39.0000    0.0    0.0            112050  33.4276      A36
# 8     female  53.0000    2.0    0.0             11769  51.4792     C101
# 9       male  71.0000    0.0    0.0          PC 17609  49.5042      NaN
# 10      male  47.0000    1.0    0.0          PC 17757  33.4276  C62 C64
# 11    female  18.0000    1.0    0.0          PC 17757  33.4276  C62 C64
# 12    female  24.0000    0.0    0.0          PC 17477  69.3000      B35
# 13    female  26.0000    0.0    0.0             19877  78.8500      NaN
# 14      male  80.0000    0.0    0.0             27042  30.0000      A23
# 15      male      NaN    0.0    0.0          PC 17318  25.9250      NaN
# 16      male  24.0000    0.0    1.0          PC 17558  33.4276  B58 B60
# 17    female  50.0000    0.0    1.0          PC 17558  33.4276  B58 B60
# 18    female  32.0000    0.0    0.0             11813  76.2917      D15
# 19      male  36.0000    0.0    0.0             13050  75.2417       C6
# 20      male  37.0000    1.0    1.0             11751  52.5542      D35
# 21    female  47.0000    1.0    1.0             11751  52.5542      D35
# 22      male  26.0000    0.0    0.0            111369  30.0000     C148
# 23    female  42.0000    0.0    0.0          PC 17757  33.4276      NaN
# 24    female  29.0000    0.0    0.0          PC 17483  33.4276      C97
# 25      male  25.0000    0.0    0.0             13905  26.0000      NaN
# 26      male  25.0000    1.0    0.0             11967  91.0792      B49
# 27    female  19.0000    1.0    0.0             11967  91.0792      B49
# 28    female  35.0000    0.0    0.0          PC 17760  33.4276      C99
# 29      male  28.0000    0.0    0.0            110564  26.5500      C52
# ...      ...      ...    ...    ...               ...      ...      ...
# 1281    male  22.0000    0.0    0.0            349252   7.8958      NaN
# 1282    male  22.0000    0.0    0.0            345767   9.0000      NaN
# 1283    male      NaN    0.0    0.0            359309   8.0500      NaN
# 1284    male      NaN    0.0    0.0        C.A. 49867   7.5500      NaN
# 1285    male      NaN    0.0    0.0  SOTON/OQ 3101316   8.0500      NaN
# 1286    male  32.5000    0.0    0.0            345775   9.5000      NaN
# 1287  female  38.0000    0.0    0.0              2688   7.2292      NaN
# 1288    male  51.0000    0.0    0.0            347064   7.7500      NaN
# 1289    male  18.0000    1.0    0.0           3101267  33.4276      NaN
# 1290    male  21.0000    1.0    0.0           3101266  33.4276      NaN
# 1291  female  47.0000    1.0    0.0            363272  33.4276      NaN
# 1292    male      NaN    0.0    0.0              3410   8.7125      NaN
# 1293    male      NaN    0.0    0.0     S.O./P.P. 751   7.5500      NaN
# 1294    male      NaN    0.0    0.0          A/5 2466   8.0500      NaN
# 1295    male  28.5000    0.0    0.0             54636  16.1000      NaN
# 1296    male  21.0000    0.0    0.0  SOTON/OQ 3101317   7.2500      NaN
# 1297    male  27.0000    0.0    0.0            315154   8.6625      NaN
# 1298    male      NaN    0.0    0.0        A/4. 34244   7.2500      NaN
# 1299    male  36.0000    0.0    0.0            345771   9.5000      NaN
# 1300    male  27.0000    1.0    0.0              2659  14.4542      NaN
# 1301     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1302     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1303     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1304     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1305     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1306     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1307     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1308     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1309     NaN      NaN    NaN    NaN               NaN      NaN      NaN
# 1310     NaN      NaN    NaN    NaN               NaN      NaN      NaN
#
#      embarked boat   body                           home.dest
# 0           S    2    NaN                        St Louis, MO
# 1           S   11    NaN     Montreal, PQ / Chesterville, ON
# 2           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 3           S  NaN  135.0     Montreal, PQ / Chesterville, ON
# 4           S  NaN    NaN     Montreal, PQ / Chesterville, ON
# 5           S    3    NaN                        New York, NY
# 6           S   10    NaN                          Hudson, NY
# 7           S  NaN    NaN                         Belfast, NI
# 8           S    D    NaN                 Bayside, Queens, NY
# 9           C  NaN   22.0                 Montevideo, Uruguay
# 10          C  NaN  124.0                        New York, NY
# 11          C    4    NaN                        New York, NY
# 12          C    9    NaN                       Paris, France
# 13          S    6    NaN                                 NaN
# 14          S    B    NaN                       Hessle, Yorks
# 15          S  NaN    NaN                        New York, NY
# 16          C  NaN    NaN                        Montreal, PQ
# 17          C    6    NaN                        Montreal, PQ
# 18          C    8    NaN                                 NaN
# 19          C    A    NaN                        Winnipeg, MN
# 20          S    5    NaN                        New York, NY
# 21          S    5    NaN                        New York, NY
# 22          C    5    NaN                        New York, NY
# 23          C    4    NaN                                 NaN
# 24          S    8    NaN                                 NaN
# 25          C  NaN  148.0                   San Francisco, CA
# 26          C    7    NaN                        Dowagiac, MI
# 27          C    7    NaN                        Dowagiac, MI
# 28          S    8    NaN                                 NaN
# 29          S    D    NaN  Stockholm, Sweden / Washington, DC
# ...       ...  ...    ...                                 ...
# 1281        S  NaN    NaN                                 NaN
# 1282        S  NaN    NaN      Antwerp, Belgium / Stanton, OH
# 1283        S  NaN    NaN                                 NaN
# 1284        S  NaN    NaN                                 NaN
# 1285        S  NaN    NaN                                 NaN
# 1286        S  NaN  298.0                                 NaN
# 1287        C    C    NaN                                 NaN
# 1288        S  NaN    NaN                                 NaN
# 1289        S  NaN  314.0                                 NaN
# 1290        S  NaN    NaN                                 NaN
# 1291        S  NaN    NaN                                 NaN
# 1292        S  NaN    NaN                                 NaN
# 1293        S  NaN    NaN                                 NaN
# 1294        S  NaN    NaN                                 NaN
# 1295        S  NaN   14.0                                 NaN
# 1296        S  NaN    NaN                                 NaN
# 1297        S  NaN  131.0                                 NaN
# 1298        S  NaN    NaN                                 NaN
# 1299        S  NaN    NaN                                 NaN
# 1300        C    C    NaN                                 NaN
# 1301      NaN  NaN    NaN                                 NaN
# 1302      NaN  NaN    NaN                                 NaN
# 1303      NaN  NaN    NaN                                 NaN
# 1304      NaN  NaN    NaN                                 NaN
# 1305      NaN  NaN    NaN                                 NaN
# 1306      NaN  NaN    NaN                                 NaN
# 1307      NaN  NaN    NaN                                 NaN
# 1308      NaN  NaN    NaN                                 NaN
# 1309      NaN  NaN    NaN                                 NaN
# 1310      NaN  NaN    NaN                                 NaN
#
# [1311 rows x 14 columns]

# %% [markdown]
# ## Question 2 (50 points)

# %% [markdown]
# ### Load the contents of 'titanic2.csv', look at the head of the data for its structure and combine it with the previous dataframe

# %%
data_filename2 = '2949741_3_titanic2.csv'
data2 = pd.read_csv(data_filename)

# %%
data2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Plot a scatter plot of 'age' vs 'fare' for your data and calculate the correlation between these two columns

# %%
# sns.catplot('fare', data= data2, hue= 'age', kind=  'count')
rng = np.random.RandomState(0)
plt.scatter(data2['age'], data2['fare'], alpha= 0.3, cmap='viridis')

plt.xlabel('age')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
#correlation between these two columns
data2['age'].corr(data2['fare'])
# Out:
# 0.1786571382948856

# %% [markdown]
# ### Drop 'name', 'cabin', 'boat', 'body','home.dest', 'embarked', 'ticket' columns

# %%
data3 = data2.drop([ 'name', 'cabin', 'boat', 'body','home.dest', 'embarked', 'ticket'], axis=1)
data3.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare
# 0     1.0       1.0  female  29.0000    0.0    0.0  211.3375
# 1     1.0       1.0    male   0.9167    1.0    2.0  151.5500
# 2     1.0       0.0  female   2.0000    1.0    2.0  151.5500
# 3     1.0       0.0    male  30.0000    1.0    2.0  151.5500
# 4     1.0       0.0  female  25.0000    1.0    2.0  151.5500

# %% [markdown]
# # Filling missing data in 'age' column by using an educated guess:

# %% [markdown]
# ### Write a function that takes two columns, 'age' and 'pclass', as input and depending on which pclass, if the age is NaN (command: pd.isnull(age)   ) it returns age 40, 30 or 25. For example, if input is [NaN, 1], it returns age = 40

# %%
dataage = data3[pd.isnull(data3['age'])]
dataage
# Out:
#       pclass  survived     sex  age  sibsp  parch      fare
# 15       1.0       0.0    male  NaN    0.0    0.0   25.9250
# 37       1.0       1.0    male  NaN    0.0    0.0   26.5500
# 40       1.0       0.0    male  NaN    0.0    0.0   39.6000
# 46       1.0       0.0    male  NaN    0.0    0.0   31.0000
# 59       1.0       1.0  female  NaN    0.0    0.0   27.7208
# 69       1.0       1.0  female  NaN    0.0    1.0   55.0000
# 70       1.0       0.0    male  NaN    0.0    0.0    0.0000
# 74       1.0       0.0    male  NaN    0.0    0.0   52.0000
# 80       1.0       0.0    male  NaN    0.0    0.0   26.5500
# 106      1.0       0.0    male  NaN    0.0    0.0  221.7792
# 107      1.0       1.0  female  NaN    0.0    0.0   31.6833
# 108      1.0       1.0  female  NaN    0.0    0.0  110.8833
# 118      1.0       0.0    male  NaN    0.0    0.0   26.5500
# 121      1.0       1.0  female  NaN    1.0    0.0  133.6500
# 125      1.0       0.0    male  NaN    0.0    0.0    0.0000
# 134      1.0       1.0  female  NaN    1.0    0.0   89.1042
# 147      1.0       0.0    male  NaN    0.0    0.0   42.4000
# 152      1.0       1.0    male  NaN    0.0    0.0   30.0000
# 157      1.0       0.0    male  NaN    0.0    0.0   51.8625
# 166      1.0       0.0    male  NaN    0.0    0.0   30.6958
# 176      1.0       1.0  female  NaN    1.0    0.0   51.8625
# 179      1.0       0.0    male  NaN    0.0    0.0   26.5500
# 184      1.0       0.0    male  NaN    0.0    0.0   27.7208
# 196      1.0       1.0    male  NaN    0.0    0.0   29.7000
# 204      1.0       1.0  female  NaN    1.0    0.0   82.1708
# 219      1.0       1.0    male  NaN    0.0    0.0   25.7417
# 223      1.0       0.0    male  NaN    0.0    0.0    0.0000
# 235      1.0       1.0    male  NaN    0.0    0.0   39.6000
# 237      1.0       0.0    male  NaN    0.0    0.0  227.5250
# 241      1.0       0.0    male  NaN    0.0    0.0   50.0000
# ...      ...       ...     ...  ...    ...    ...       ...
# 1222     3.0       0.0    male  NaN    0.0    0.0    7.8958
# 1242     3.0       0.0    male  NaN    1.0    0.0    6.4375
# 1243     3.0       0.0    male  NaN    0.0    0.0    6.4375
# 1244     3.0       0.0    male  NaN    0.0    0.0    7.2250
# 1246     3.0       0.0    male  NaN    0.0    0.0    8.0500
# 1247     3.0       0.0    male  NaN    1.0    0.0   16.1000
# 1248     3.0       1.0  female  NaN    1.0    0.0   16.1000
# 1250     3.0       0.0    male  NaN    0.0    0.0    7.7500
# 1251     3.0       0.0    male  NaN    0.0    0.0    7.8958
# 1254     3.0       0.0    male  NaN    0.0    0.0    7.2292
# 1256     3.0       0.0    male  NaN    0.0    0.0    7.2292
# 1263     3.0       0.0    male  NaN    1.0    1.0   14.5000
# 1269     3.0       0.0    male  NaN    0.0    0.0    9.5000
# 1283     3.0       0.0    male  NaN    0.0    0.0    8.0500
# 1284     3.0       0.0    male  NaN    0.0    0.0    7.5500
# 1285     3.0       0.0    male  NaN    0.0    0.0    8.0500
# 1292     3.0       0.0    male  NaN    0.0    0.0    8.7125
# 1293     3.0       0.0    male  NaN    0.0    0.0    7.5500
# 1294     3.0       0.0    male  NaN    0.0    0.0    8.0500
# 1298     3.0       0.0    male  NaN    0.0    0.0    7.2500
# 1301     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1302     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1303     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1304     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1305     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1306     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1307     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1308     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1309     NaN       NaN     NaN  NaN    NaN    NaN       NaN
# 1310     NaN       NaN     NaN  NaN    NaN    NaN       NaN
#
# [271 rows x 7 columns]

# %%
def fill_miss(b): 
    if b == 1.0:
        return 40
    elif b == 2.0:
        return 30
    elif b == 3.0:
        return 25

# %% [markdown]
# ### Use apply to clean up age database for NaN using the function created above

# %%
dataage['age'] = dataage['pclass'].apply(fill_miss)
dataage
# Out:
# c:\users\deepak patel\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       pclass  survived     sex   age  sibsp  parch      fare
# 15       1.0       0.0    male  40.0    0.0    0.0   25.9250
# 37       1.0       1.0    male  40.0    0.0    0.0   26.5500
# 40       1.0       0.0    male  40.0    0.0    0.0   39.6000
# 46       1.0       0.0    male  40.0    0.0    0.0   31.0000
# 59       1.0       1.0  female  40.0    0.0    0.0   27.7208
# 69       1.0       1.0  female  40.0    0.0    1.0   55.0000
# 70       1.0       0.0    male  40.0    0.0    0.0    0.0000
# 74       1.0       0.0    male  40.0    0.0    0.0   52.0000
# 80       1.0       0.0    male  40.0    0.0    0.0   26.5500
# 106      1.0       0.0    male  40.0    0.0    0.0  221.7792
# 107      1.0       1.0  female  40.0    0.0    0.0   31.6833
# 108      1.0       1.0  female  40.0    0.0    0.0  110.8833
# 118      1.0       0.0    male  40.0    0.0    0.0   26.5500
# 121      1.0       1.0  female  40.0    1.0    0.0  133.6500
# 125      1.0       0.0    male  40.0    0.0    0.0    0.0000
# 134      1.0       1.0  female  40.0    1.0    0.0   89.1042
# 147      1.0       0.0    male  40.0    0.0    0.0   42.4000
# 152      1.0       1.0    male  40.0    0.0    0.0   30.0000
# 157      1.0       0.0    male  40.0    0.0    0.0   51.8625
# 166      1.0       0.0    male  40.0    0.0    0.0   30.6958
# 176      1.0       1.0  female  40.0    1.0    0.0   51.8625
# 179      1.0       0.0    male  40.0    0.0    0.0   26.5500
# 184      1.0       0.0    male  40.0    0.0    0.0   27.7208
# 196      1.0       1.0    male  40.0    0.0    0.0   29.7000
# 204      1.0       1.0  female  40.0    1.0    0.0   82.1708
# 219      1.0       1.0    male  40.0    0.0    0.0   25.7417
# 223      1.0       0.0    male  40.0    0.0    0.0    0.0000
# 235      1.0       1.0    male  40.0    0.0    0.0   39.6000
# 237      1.0       0.0    male  40.0    0.0    0.0  227.5250
# 241      1.0       0.0    male  40.0    0.0    0.0   50.0000
# ...      ...       ...     ...   ...    ...    ...       ...
# 1222     3.0       0.0    male  25.0    0.0    0.0    7.8958
# 1242     3.0       0.0    male  25.0    1.0    0.0    6.4375
# 1243     3.0       0.0    male  25.0    0.0    0.0    6.4375
# 1244     3.0       0.0    male  25.0    0.0    0.0    7.2250
# 1246     3.0       0.0    male  25.0    0.0    0.0    8.0500
# 1247     3.0       0.0    male  25.0    1.0    0.0   16.1000
# 1248     3.0       1.0  female  25.0    1.0    0.0   16.1000
# 1250     3.0       0.0    male  25.0    0.0    0.0    7.7500
# 1251     3.0       0.0    male  25.0    0.0    0.0    7.8958
# 1254     3.0       0.0    male  25.0    0.0    0.0    7.2292
# 1256     3.0       0.0    male  25.0    0.0    0.0    7.2292
# 1263     3.0       0.0    male  25.0    1.0    1.0   14.5000
# 1269     3.0       0.0    male  25.0    0.0    0.0    9.5000
# 1283     3.0       0.0    male  25.0    0.0    0.0    8.0500
# 1284     3.0       0.0    male  25.0    0.0    0.0    7.5500
# 1285     3.0       0.0    male  25.0    0.0    0.0    8.0500
# 1292     3.0       0.0    male  25.0    0.0    0.0    8.7125
# 1293     3.0       0.0    male  25.0    0.0    0.0    7.5500
# 1294     3.0       0.0    male  25.0    0.0    0.0    8.0500
# 1298     3.0       0.0    male  25.0    0.0    0.0    7.2500
# 1301     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1302     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1303     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1304     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1305     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1306     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1307     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1308     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1309     NaN       NaN     NaN   NaN    NaN    NaN       NaN
# 1310     NaN       NaN     NaN   NaN    NaN    NaN       NaN
#
# [271 rows x 7 columns]

# %% [markdown]
# ### In the 'fare' column, isolate and display the row where there is NaN

# %%
data3[pd.isnull(data3['fare'])]
# Out:
#       pclass  survived   sex   age  sibsp  parch  fare
# 1226     3.0       0.0  male  60.5    0.0    0.0   NaN
# 1301     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1302     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1303     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1304     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1305     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1306     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1307     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1308     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1309     NaN       NaN   NaN   NaN    NaN    NaN   NaN
# 1310     NaN       NaN   NaN   NaN    NaN    NaN   NaN

# %% [markdown]
# ### Using apply fuction, convert the data in 'sex' column to zeros and ones: if female, replace by 1, otherwise by 0

# %%
def cnvrt(s):
    
    if s == 'male':
        return 0
    elif s == 'female':
        return 1
    
data3['sex'] = data3['sex'].apply(cnvrt)
data3
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare
# 0        1.0       1.0  1.0  29.0000    0.0    0.0  211.3375
# 1        1.0       1.0  0.0   0.9167    1.0    2.0  151.5500
# 2        1.0       0.0  1.0   2.0000    1.0    2.0  151.5500
# 3        1.0       0.0  0.0  30.0000    1.0    2.0  151.5500
# 4        1.0       0.0  1.0  25.0000    1.0    2.0  151.5500
# 5        1.0       1.0  0.0  48.0000    0.0    0.0   26.5500
# 6        1.0       1.0  1.0  63.0000    1.0    0.0   77.9583
# 7        1.0       0.0  0.0  39.0000    0.0    0.0    0.0000
# 8        1.0       1.0  1.0  53.0000    2.0    0.0   51.4792
# 9        1.0       0.0  0.0  71.0000    0.0    0.0   49.5042
# 10       1.0       0.0  0.0  47.0000    1.0    0.0  227.5250
# 11       1.0       1.0  1.0  18.0000    1.0    0.0  227.5250
# 12       1.0       1.0  1.0  24.0000    0.0    0.0   69.3000
# 13       1.0       1.0  1.0  26.0000    0.0    0.0   78.8500
# 14       1.0       1.0  0.0  80.0000    0.0    0.0   30.0000
# 15       1.0       0.0  0.0      NaN    0.0    0.0   25.9250
# 16       1.0       0.0  0.0  24.0000    0.0    1.0  247.5208
# 17       1.0       1.0  1.0  50.0000    0.0    1.0  247.5208
# 18       1.0       1.0  1.0  32.0000    0.0    0.0   76.2917
# 19       1.0       0.0  0.0  36.0000    0.0    0.0   75.2417
# 20       1.0       1.0  0.0  37.0000    1.0    1.0   52.5542
# 21       1.0       1.0  1.0  47.0000    1.0    1.0   52.5542
# 22       1.0       1.0  0.0  26.0000    0.0    0.0   30.0000
# 23       1.0       1.0  1.0  42.0000    0.0    0.0  227.5250
# 24       1.0       1.0  1.0  29.0000    0.0    0.0  221.7792
# 25       1.0       0.0  0.0  25.0000    0.0    0.0   26.0000
# 26       1.0       1.0  0.0  25.0000    1.0    0.0   91.0792
# 27       1.0       1.0  1.0  19.0000    1.0    0.0   91.0792
# 28       1.0       1.0  1.0  35.0000    0.0    0.0  135.6333
# 29       1.0       1.0  0.0  28.0000    0.0    0.0   26.5500
# ...      ...       ...  ...      ...    ...    ...       ...
# 1281     3.0       0.0  0.0  22.0000    0.0    0.0    7.8958
# 1282     3.0       0.0  0.0  22.0000    0.0    0.0    9.0000
# 1283     3.0       0.0  0.0      NaN    0.0    0.0    8.0500
# 1284     3.0       0.0  0.0      NaN    0.0    0.0    7.5500
# 1285     3.0       0.0  0.0      NaN    0.0    0.0    8.0500
# 1286     3.0       0.0  0.0  32.5000    0.0    0.0    9.5000
# 1287     3.0       1.0  1.0  38.0000    0.0    0.0    7.2292
# 1288     3.0       0.0  0.0  51.0000    0.0    0.0    7.7500
# 1289     3.0       0.0  0.0  18.0000    1.0    0.0    6.4958
# 1290     3.0       0.0  0.0  21.0000    1.0    0.0    6.4958
# 1291     3.0       1.0  1.0  47.0000    1.0    0.0    7.0000
# 1292     3.0       0.0  0.0      NaN    0.0    0.0    8.7125
# 1293     3.0       0.0  0.0      NaN    0.0    0.0    7.5500
# 1294     3.0       0.0  0.0      NaN    0.0    0.0    8.0500
# 1295     3.0       0.0  0.0  28.5000    0.0    0.0   16.1000
# 1296     3.0       0.0  0.0  21.0000    0.0    0.0    7.2500
# 1297     3.0       0.0  0.0  27.0000    0.0    0.0    8.6625
# 1298     3.0       0.0  0.0      NaN    0.0    0.0    7.2500
# 1299     3.0       0.0  0.0  36.0000    0.0    0.0    9.5000
# 1300     3.0       0.0  0.0  27.0000    1.0    0.0   14.4542
# 1301     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1302     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1303     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1304     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1305     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1306     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1307     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1308     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1309     NaN       NaN  NaN      NaN    NaN    NaN       NaN
# 1310     NaN       NaN  NaN      NaN    NaN    NaN       NaN
#
# [1311 rows x 7 columns]

# %% [markdown]
# ### Display the top rows for 'sex' column

# %%
data3['sex'].head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: sex, dtype: float64

# %% [markdown]
# ### Confirm that the contents of the 'sex' column are integers by showing the type of one content (zero's index, first, etc) or using the info command

# %%
data3['sex'][0].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### In 'fare' column, replace NaN with the mean of the column

# %%
fmean = data3['fare'].mean()
def frep(f):
    
    if pd.isnull(f):
        return fmean
    return f
    
data3['fare'] = data3['fare'].apply(frep)
data4 = data3
data4
# Out:
#       pclass  survived  sex      age  sibsp  parch        fare
# 0        1.0       1.0  1.0  29.0000    0.0    0.0  211.337500
# 1        1.0       1.0  0.0   0.9167    1.0    2.0  151.550000
# 2        1.0       0.0  1.0   2.0000    1.0    2.0  151.550000
# 3        1.0       0.0  0.0  30.0000    1.0    2.0  151.550000
# 4        1.0       0.0  1.0  25.0000    1.0    2.0  151.550000
# 5        1.0       1.0  0.0  48.0000    0.0    0.0   26.550000
# 6        1.0       1.0  1.0  63.0000    1.0    0.0   77.958300
# 7        1.0       0.0  0.0  39.0000    0.0    0.0    0.000000
# 8        1.0       1.0  1.0  53.0000    2.0    0.0   51.479200
# 9        1.0       0.0  0.0  71.0000    0.0    0.0   49.504200
# 10       1.0       0.0  0.0  47.0000    1.0    0.0  227.525000
# 11       1.0       1.0  1.0  18.0000    1.0    0.0  227.525000
# 12       1.0       1.0  1.0  24.0000    0.0    0.0   69.300000
# 13       1.0       1.0  1.0  26.0000    0.0    0.0   78.850000
# 14       1.0       1.0  0.0  80.0000    0.0    0.0   30.000000
# 15       1.0       0.0  0.0      NaN    0.0    0.0   25.925000
# 16       1.0       0.0  0.0  24.0000    0.0    1.0  247.520800
# 17       1.0       1.0  1.0  50.0000    0.0    1.0  247.520800
# 18       1.0       1.0  1.0  32.0000    0.0    0.0   76.291700
# 19       1.0       0.0  0.0  36.0000    0.0    0.0   75.241700
# 20       1.0       1.0  0.0  37.0000    1.0    1.0   52.554200
# 21       1.0       1.0  1.0  47.0000    1.0    1.0   52.554200
# 22       1.0       1.0  0.0  26.0000    0.0    0.0   30.000000
# 23       1.0       1.0  1.0  42.0000    0.0    0.0  227.525000
# 24       1.0       1.0  1.0  29.0000    0.0    0.0  221.779200
# 25       1.0       0.0  0.0  25.0000    0.0    0.0   26.000000
# 26       1.0       1.0  0.0  25.0000    1.0    0.0   91.079200
# 27       1.0       1.0  1.0  19.0000    1.0    0.0   91.079200
# 28       1.0       1.0  1.0  35.0000    0.0    0.0  135.633300
# 29       1.0       1.0  0.0  28.0000    0.0    0.0   26.550000
# ...      ...       ...  ...      ...    ...    ...         ...
# 1281     3.0       0.0  0.0  22.0000    0.0    0.0    7.895800
# 1282     3.0       0.0  0.0  22.0000    0.0    0.0    9.000000
# 1283     3.0       0.0  0.0      NaN    0.0    0.0    8.050000
# 1284     3.0       0.0  0.0      NaN    0.0    0.0    7.550000
# 1285     3.0       0.0  0.0      NaN    0.0    0.0    8.050000
# 1286     3.0       0.0  0.0  32.5000    0.0    0.0    9.500000
# 1287     3.0       1.0  1.0  38.0000    0.0    0.0    7.229200
# 1288     3.0       0.0  0.0  51.0000    0.0    0.0    7.750000
# 1289     3.0       0.0  0.0  18.0000    1.0    0.0    6.495800
# 1290     3.0       0.0  0.0  21.0000    1.0    0.0    6.495800
# 1291     3.0       1.0  1.0  47.0000    1.0    0.0    7.000000
# 1292     3.0       0.0  0.0      NaN    0.0    0.0    8.712500
# 1293     3.0       0.0  0.0      NaN    0.0    0.0    7.550000
# 1294     3.0       0.0  0.0      NaN    0.0    0.0    8.050000
# 1295     3.0       0.0  0.0  28.5000    0.0    0.0   16.100000
# 1296     3.0       0.0  0.0  21.0000    0.0    0.0    7.250000
# 1297     3.0       0.0  0.0  27.0000    0.0    0.0    8.662500
# 1298     3.0       0.0  0.0      NaN    0.0    0.0    7.250000
# 1299     3.0       0.0  0.0  36.0000    0.0    0.0    9.500000
# 1300     3.0       0.0  0.0  27.0000    1.0    0.0   14.454200
# 1301     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1302     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1303     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1304     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1305     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1306     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1307     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1308     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1309     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
# 1310     NaN       NaN  NaN      NaN    NaN    NaN   33.427608
#
# [1311 rows x 7 columns]

# %% [markdown]
# ### Drop any leftover NaN in the dataframe

# %%
#Answer here
data5 = data3.dropna()

# %% [markdown]
# ### Display the head of cleaned dataframe

# %%
data5.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch      fare
# 0     1.0       1.0  1.0  29.0000    0.0    0.0  211.3375
# 1     1.0       1.0  0.0   0.9167    1.0    2.0  151.5500
# 2     1.0       0.0  1.0   2.0000    1.0    2.0  151.5500
# 3     1.0       0.0  0.0  30.0000    1.0    2.0  151.5500
# 4     1.0       0.0  1.0  25.0000    1.0    2.0  151.5500

# %% [markdown]
# # QED!
